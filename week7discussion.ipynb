# %% [markdown]
# <a href="https://colab.research.google.com/github/wbjimmer/Machine-Learning/blob/main/week7discussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 12.1 Exercise

# %%
import requests

# %%
response = requests.get('https://www.python.org')

# %%
response.content  # gives back the page's HTML

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.content, 'html5lib')

# %%
text = soup.get_text(strip=True)  # text without tags

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud

# %%
wordcloud = wordcloud.generate(text)

# %%
wordcloud = wordcloud.to_file('test.png')

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
